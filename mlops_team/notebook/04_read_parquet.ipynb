# %%
import pandas as pd
import s3fs

s3_path = 's3://mlops-prj/data/weather/raw/year=2025/month=06/day=06/data.parquet'

df = pd.read_parquet(s3_path)
print(df)
# Out:
#        ObservationTime  StationID  WindDirection  WindSpeed  GustDirection  \
# 0  2025-06-06 00:00:00        108             18        1.0             -9
# 1  2025-06-06 01:00:00        108              2        1.4             -9
# 2  2025-06-06 02:00:00        108             34        1.3             -9
# 3  2025-06-06 03:00:00        108              2        1.7             -9
# 4  2025-06-06 04:00:00        108              5        1.7             -9
# 5  2025-06-06 05:00:00        108              5        1.6             -9
# 6  2025-06-06 06:00:00        108              5        1.4             -9
# 7  2025-06-06 07:00:00        108              5        2.0             -9
# 8  2025-06-06 08:00:00        108              5        1.9             -9
# 9  2025-06-06 09:00:00        108              9        1.7             -9
# 10 2025-06-06 10:00:00        108             18        3.7             -9
# ...

# %%
s3_path = 's3://mlops-prj/data/weather/raw/year=2025/month=06/day=07/data.parquet'

df = pd.read_parquet(s3_path)
print(df)
# Out:
#       ObservationTime  StationID  WindDirection  WindSpeed  GustDirection  \
# 0 2025-06-07 22:00:00        108             27        2.7             -9
#
#    GustSpeed  GustTime  LocalPressure  SeaLevelPressure  PressureTrend  ...  \
# 0       -9.0        -9          998.0            1007.8             -9  ...
#
#    SoilTemperature5cm  SoilTemperature10cm  SoilTemperature20cm  \
# 0                24.6                 24.1                 23.0
#
#    SoilTemperature30cm  SeaCondition  WaveHeight  MaxWindForce  \
# 0                 21.6            -9        -9.0            -9
#
#    PrecipitationData  ObservationType  hour
# 0                  4                1    22
#
# [1 rows x 47 columns]
